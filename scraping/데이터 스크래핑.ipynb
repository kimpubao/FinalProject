# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import re
import numpy as np
from tqdm import tqdm

movies = pd.read_excel('movie15.xls', skiprows=4)
movies.head()
# Out:
#                       영화명                   영화명(영문)    제작연도 제작국가  유형  \
# 0                  부활의 노래  The Song Of Resurrection  1990.0   한국  장편
# 1      젖은장모-사위 대물에 눈 뒤집히네                       NaN  2022.0   일본  장편
# 2     점장님 팬티 내릴게요 눈감아 주세요                       NaN  2022.0   일본  장편
# 3     옆집여자-남편 대신 시원하게 싸줬다                       NaN  2023.0   일본  장편
# 4  물 넘치는 섹파-방금 쌌는데 또 싸고싶어                       NaN  2023.0   일본  장편
#
#                    장르 제작상태        감독      제작사
# 0                 드라마   개봉       이정국  새빛영화제작소
# 1  성인물(에로),드라마,멜로/로맨스   개봉     츠지 코지      NaN
# 2  성인물(에로),드라마,멜로/로맨스   개봉  타카야마 켄타로      NaN
# 3  성인물(에로),드라마,멜로/로맨스   개봉  타카야마 켄타로      NaN
# 4  성인물(에로),드라마,멜로/로맨스   개봉     히무 롯쿠      NaN

# %%
def genre(x):
    if '성인물(에로)' not in x:
        return x
movies['장르'] = movies.장르.apply(genre)
movies = movies[~movies['장르'].isnull()].reset_index(drop=True)

# %%
print(len(movies.장르.unique()))
movies.head()
# Out:
# 885
#           영화명                   영화명(영문)    제작연도 제작국가  유형         장르 제작상태  \
# 0      부활의 노래  The Song Of Resurrection  1990.0   한국  장편        드라마   개봉
# 1      이매큘레이트                Immaculate  2024.0   미국  장편     공포(호러)   개봉
# 2  러브 라이즈 블리딩        Love Lies Bleeding  2023.0   미국  장편  범죄,멜로/로맨스   개봉
# 3           짱                   Top Dog  2018.0   한국  장편         액션   개봉
# 4    싸움의 기술 2     The Art of Fighting 2  2020.0   한국  장편         액션   개봉
#
#        감독                제작사
# 0     이정국            새빛영화제작소
# 1  마이클 모한                NaN
# 2  로즈 글래스                NaN
# 3     송재덕  (주)영화사 사계절,펀펀한영화사
# 4     김희성         (주)영화사 사계절

# %%
movies = movies.영화명.tolist()
movies[:15]
# Out:
# ['부활의 노래',
#  '이매큘레이트',
#  '러브 라이즈 블리딩',
#  '짱',
#  '싸움의 기술 2',
#  '아이윌 송',
#  '싸움의 기술',
#  '깡패들',
#  '전야',
#  '심장박동 조작극',
#  '비포 선셋',
#  '사일런트 나잇',
#  '명탐정 코난: 100만 달러의 펜타그램',
#  '그리고 바통은 넘겨졌다',
#  '더 납작 엎드릴게요']

# %% [markdown]
# 스크래핑이 안되는 건 아닌데 영화 평점이 없는 데이터는 추가가 안돼서 문제임;;

# %%
url = 'https://namu.wiki/w/' # %EC%82%B4%EC%9D%B8%EC%9D%98%20%EC%B6%94%EC%96%B5
pd_movies = []
content = ''
cnt = 0
for movie in tqdm(movies):
    try:
        page = requests.get(url + movie)
        html = BeautifulSoup(page.text, 'html.parser')

        soup1 = html.select('#app div div div div') # 시놉시스
        soup2 = html.select('#app div div div div .wiki-paragraph') # 테이블 형식 데이터 수집

        evaluation = []
        st = 0

        for s in soup1:
            if s.text != '':
                if '시놉시스[편집]' in s.text:
                    content = s.text
                    break
        lst = content.split('[편집]')
        for i, v in enumerate(lst):
            if v[-4:] == '시놉시스':
                synopsys = lst[i+1]
                break
        for i, v in enumerate(soup1):
            if '평가[편집]' in v.text:
                evaluation.append(soup1[i:i+10])
        evaluation = evaluation[-1]
    except:
        page = requests.get(url + movie +'(영화)')
        html = BeautifulSoup(page.text, 'html.parser')

        soup1 = html.select('#app div div div div') # 시놉시스
        soup2 = html.select('#app div div div div .wiki-paragraph') # 테이블 형식 데이터 수집

        evaluation = []
        st = 0

        for s in soup1:
            if s.text != '':
                if '시놉시스[편집]' in s.text:
                    content = s.text
                    break
        lst = content.split('[편집]')
        for i, v in enumerate(lst):
            if v[-4:] == '시놉시스':
                synopsys = lst[i+1]
                break
        for i, v in enumerate(soup1):
            if '평가[편집]' in v.text:
                evaluation.append(soup1[i:i+10])
    
    try:
        evaluation = evaluation[-1]
        lst = [] # 영화에 대한 정보를 담는 리스트
        for s in soup2[1:]: # 영화의 정보, 1은 총 데이터 묶음이므로 생략
            if s.text != '':
                if s.text == '장르':
                    st = 1
                elif '개요' in s.text:
                    st = 0
                    break
                if st == 1:
                    lst.append(s.text)
            if '개요' in s.text:
                break

        table_data = []
        data = []
        idx = -1

        if len(evaluation[idx]) == 0: # 페이지마다 스크래핑되는 경우와 안되는 경우가 있음.
            idx = -2                  # 인덱스를 바꾸면 가져올 수 있음

        for i in evaluation[idx].select('a'):
            if ('http' not in i.attrs['title']) & (i.attrs['title'] != '') & (len(i.attrs['title']) < 30):
                try:
                    if '네이버 영화' in table_data[-1]: # 네이버 영화는 동일한 데이터가 2번 입력됨
                        del data[0]
                except:
                    pass
                table_data.append(data)
                table_data.append(i.attrs['title'])
                data = []
            if (i.text != '') & bool(re.search(r'[\d%/]', i.text)) & (len(data) < 2) & ~bool(re.search(r'[\[\]]', i.text)): 
                # 데이터값에는 다양한 데이터가 들어가지만 주로 1/10 같은 분수 표현과 숫자로 구성 되어 있음. 
                # 또한 %도 들어가며 데이터는 최대 2개만 들어가는 것으로 보임
                data.append(i.text)

        
        try: # max_length 변수 참고
            # 평가 기관 및 점수 데이터 가공
            table_data = table_data[1:] # 첫째 데이터는 비어있음
            eval_dict = dict(zip(table_data[::2],table_data[1::2])) # dict화
            
            max_length = max(len(v) for v in eval_dict.values()) # 평가 챕터가 열려있지 않으면 에러 발생하므로 try문으로 묶음
            for k, v in eval_dict.items(): # 데이터 길이 맞추기
                if len(v) < max_length:
                    eval_dict[k] = v + [np.nan] * (max_length - len(v))

            eval_df = pd.DataFrame(eval_dict) # 데이터프레임화
            eval_df = eval_df.dropna(axis=1, how='all') # 데이터가 전부 비어있으면 삭제
            eval_df = eval_df.transpose().reset_index()
            eval_df.columns = ['평가', '점수1', '점수2']

            # 영화 정보 가공
            lst.insert(0, '영화명')
            lst.insert(1, movie)
            df = pd.DataFrame(lst)
            df = pd.concat([df.iloc[::2].reset_index(drop=True), df.iloc[1::2].reset_index(drop=True)], axis=1)
            df.columns = ['kind', 'content']
            df.set_index(df.kind, inplace=True)
            df = df.drop('kind', axis=1)
            pd_movies.append([eval_df,df])
            
        except Exception:
            pass
    except:
        pass
    cnt += 1
    if cnt == 50:
        break
# Out:
#   0%|          | 49/13306 [00:35<2:40:23,  1.38it/s]

# %% [markdown]
# 49개중 4개만 데이터가 담김;;
# 원인은 평가 부분에서 데이터에 담기지 않으면서 에러가 생겨 try문을 벗어나 데이터를 담지 않게 됨

# %%
len(pd_movies)
# Out:
# 4

# %%
evaluation
# Out:
# [<div data-v-95bee609="" style="b10dfw+X"><h2 class="wiki-heading" data-v-95bee609=""><a data-v-95bee609="" href="#toc" id="s-8">8.</a> <span data-v-95bee609="" id="평가">평가<span class="wiki-edit-section" data-v-95bee609=""><a data-v-95bee609="" href="/edit/%EB%8C%93%EA%B8%80%EB%B6%80%EB%8C%80(%EC%98%81%ED%99%94)?section=13" rel="nofollow">[편집]</a></span></span></h2></div>,
#  <div data-v-95bee609="" style="b10dfw+X"></div>,
#  <div data-v-95bee609="" style="b10dfw+X"></div>,
#  <div data-v-95bee609="" style="b10dfw+X"></div>,
#  <div class="ou9T9n3p" data-v-95bee609="" data-v-befa586c=""><div data-v-95bee609="" style="ou9T9n3p"></div><div data-v-95bee609="" style="ou9T9n3p"><div data-v-95bee609="" style="ou9T9n3p"></div><div data-v-95bee609="" style="ou9T9n3p"><div data-v-95bee609="" style="ou9T9n3p"></div><div data-v-95bee609="" style="ou9T9n3p"><div class="wiki-heading-content" data-v-95bee609=""><div class="wiki-table-wrap table-center" data-v-95bee609="" style="width:650px"><table class="wiki-table" data-dark-style="background-color:#1c1d1f;" data-v-95bee609="" style="background-color:#fff; width:100%; border:2px solid #333;"><tbody data-v-95bee609=""><tr data-v-95bee609="" style="background-color:#333; color:#fff;"><td data-v-95bee609="" style="text-align:center;"><div class="wiki-paragraph" data-v-95bee609=""><strong data-v-95bee609="">평점 목록</strong></div></td></tr><tr data-v-95bee609=""><td data-v-95bee609="" style="text-align:center;"><div class="wiki-paragraph" data-v-95bee609=""><div data-v-95bee609="" style="margin:-5px -10px -5px -10px"><div data-v-95bee609=""><div data-v-95bee609="" style="margin:0"><div data-v-95bee609="" style="display:inline-table;display:none;width:100%;margin:-11px 0"><div class="wiki-table-wrap" data-v-95bee609="" style="width:100%"><table class="wiki-table" data-dark-style="background-color:#1c1d1f;" data-v-95bee609="" style="background-color:#fff; width:100%;"><tbody data-v-95bee609=""><tr data-v-95bee609=""><td data-v-95bee609="" style="background-color:#f6c700; width:20%;"><div class="wiki-paragraph" data-v-95bee609=""><div data-v-95bee609="" style="display:inline-block;margin:-5px;width:100px;max-width:25vw"><a class="wiki-link-internal" data-v-95bee609="" href="/w/IMDb" title="IMDb"><span class="wiki-image-align-normal" data-v-95bee609="" style="width:50%;"><span class="wiki-image-wrapper" data-v-95bee609="" style="width: 100%;"><img alt="IMDb 로고" data-v-95bee609="" src="//i.namu.wiki/i/XcJ0XFSm4_nq_AUYSCqxR7j50044CXfI1sgfRH3rDB1-vOD6zmzR2DuCM_jzYDsAR-SQEUc88e4Yfdik2hig9cXnRj3vg83LcZf8Q9tLBrZj2oLOZ3Ftp0i2PepZdOaP_7nlHF9F1sAjJlF1y4mm-w.svg" width="100%"/></span></span></a></div></div></td><td data-v-95bee609=""><div class="wiki-paragraph" data-v-95bee609=""><div data-v-95bee609="" style="display:inline-block;margin:0 5px"><a class="wiki-link-external" data-v-95bee609="" href="https://www.imdb.com/title/" rel="nofollow noopener ugc" target="_blank" title="https://www.imdb.com/title/"> <span data-dark-style="color:#fff;" data-v-95bee609="" style="color:#000">평점  / 10</span></a></div><div data-v-95bee609="" style="display:inline-block;display:none;margin:0 5px">(<a class="wiki-self-link" data-v-95bee609="" href="" title=""></a> 위<span class="wiki-size-down-3" data-v-95bee609=""><div data-v-95bee609="" style="display:inline-block;display:none;margin-left:0.5em">20XX-XX-XX 기준</div></span>)</div></div></td></tr></tbody></table></div></div><div data-v-95bee609="" style="display:inline-table;display:none;width:100%;margin:-11px 0"><div class="wiki-table-wrap" data-v-95bee609="" style="width:100%"><table class="wiki-table" data-dark-style="background-color:#1c1d1f;" data-v-95bee609="" style="background-color:#fff; width:100%;"><tbody data-v-95bee609=""><tr data-v-95bee609=""><td data-v-95bee609="" style="background-color:#f93208; width:20%;"><div class="wiki-paragraph" data-v-95bee609=""><div data-v-95bee609="" style="display:inline-block;margin:-5px;width:100px;max-width:25vw"><a class="wiki-link-internal" data-v-95bee609="" href="/w/%EB%A1%9C%ED%8A%BC%20%ED%86%A0%EB%A7%88%ED%86%A0" title="로튼 토마토"><span class="wiki-image-align-normal" data-v-95bee609="" style="width:80%;"><span class="wiki-image-wrapper" data-v-95bee609="" style="width: 100%;"><img alt="로튼 토마토 로고 화이트" data-v-95bee609="" src="//i.namu.wiki/i/UcwDzk40uD8tYdAD5h2jWkD6b9iJwR9sVLU9ko_5JWBEQUZ3s5f1y94NKfUGxMfYDDydCaNbU39-U97BLokRjSYki-CuLKg8GUD5RO2WYX6jlwvP-DHE1AGQzKCmBwru33WDXPUX2FCbp8w5Ejfibg.svg" width="100%"/></span></span></a></div></div></td><td data- ...
#  <div data-v-95bee609="" style="ou9T9n3p"></div>,
#  <div data-v-95bee609="" style="ou9T9n3p"><div data-v-95bee609="" style="ou9T9n3p"></div><div data-v-95bee609="" style="ou9T9n3p"><div data-v-95bee609="" style="ou9T9n3p"></div><div data-v-95bee609="" style="ou9T9n3p"><div class="wiki-heading-content" data-v-95bee609=""><div class="wiki-table-wrap table-center" data-v-95bee609="" style="width:650px"><table class="wiki-table" data-dark-style="background-color:#1c1d1f;" data-v-95bee609="" style="background-color:#fff; width:100%; border:2px solid #333;"><tbody data-v-95bee609=""><tr data-v-95bee609="" style="background-color:#333; color:#fff;"><td data-v-95bee609="" style="text-align:center;"><div class="wiki-paragraph" data-v-95bee609=""><strong data-v-95bee609="">평점 목록</strong></div></td></tr><tr data-v-95bee609=""><td data-v-95bee609="" style="text-align:center;"><div class="wiki-paragraph" data-v-95bee609=""><div data-v-95bee609="" style="margin:-5px -10px -5px -10px"><div data-v-95bee609=""><div data-v-95bee609="" style="margin:0"><div data-v-95bee609="" style="display:inline-table;display:none;width:100%;margin:-11px 0"><div class="wiki-table-wrap" data-v-95bee609="" style="width:100%"><table class="wiki-table" data-dark-style="background-color:#1c1d1f;" data-v-95bee609="" style="background-color:#fff; width:100%;"><tbody data-v-95bee609=""><tr data-v-95bee609=""><td data-v-95bee609="" style="background-color:#f6c700; width:20%;"><div class="wiki-paragraph" data-v-95bee609=""><div data-v-95bee609="" style="display:inline-block;margin:-5px;width:100px;max-width:25vw"><a class="wiki-link-internal" data-v-95bee609="" href="/w/IMDb" title="IMDb"><span class="wiki-image-align-normal" data-v-95bee609="" style="width:50%;"><span class="wiki-image-wrapper" data-v-95bee609="" style="width: 100%;"><img alt="IMDb 로고" data-v-95bee609="" src="//i.namu.wiki/i/XcJ0XFSm4_nq_AUYSCqxR7j50044CXfI1sgfRH3rDB1-vOD6zmzR2DuCM_jzYDsAR-SQEUc88e4Yfdik2hig9cXnRj3vg83LcZf8Q9tLBrZj2oLOZ3Ftp0i2PepZdOaP_7nlHF9F1sAjJlF1y4mm-w.svg" width="100%"/></span></span></a></div></div></td><td data-v-95bee609=""><div class="wiki-paragraph" data-v-95bee609=""><div data-v-95bee609="" style="display:inline-block;margin:0 5px"><a class="wiki-link-external" data-v-95bee609="" href="https://www.imdb.com/title/" rel="nofollow noopener ugc" target="_blank" title="https://www.imdb.com/title/"> <span data-dark-style="color:#fff;" data-v-95bee609="" style="color:#000">평점  / 10</span></a></div><div data-v-95bee609="" style="display:inline-block;display:none;margin:0 5px">(<a class="wiki-self-link" data-v-95bee609="" href="" title=""></a> 위<span class="wiki-size-down-3" data-v-95bee609=""><div data-v-95bee609="" style="display:inline-block;display:none;margin-left:0.5em">20XX-XX-XX 기준</div></span>)</div></div></td></tr></tbody></table></div></div><div data-v-95bee609="" style="display:inline-table;display:none;width:100%;margin:-11px 0"><div class="wiki-table-wrap" data-v-95bee609="" style="width:100%"><table class="wiki-table" data-dark-style="background-color:#1c1d1f;" data-v-95bee609="" style="background-color:#fff; width:100%;"><tbody data-v-95bee609=""><tr data-v-95bee609=""><td data-v-95bee609="" style="background-color:#f93208; width:20%;"><div class="wiki-paragraph" data-v-95bee609=""><div data-v-95bee609="" style="display:inline-block;margin:-5px;width:100px;max-width:25vw"><a class="wiki-link-internal" data-v-95bee609="" href="/w/%EB%A1%9C%ED%8A%BC%20%ED%86%A0%EB%A7%88%ED%86%A0" title="로튼 토마토"><span class="wiki-image-align-normal" data-v-95bee609="" style="width:80%;"><span class="wiki-image-wrapper" data-v-95bee609="" style="width: 100%;"><img alt="로튼 토마토 로고 화이트" data-v-95bee609="" src="//i.namu.wiki/i/UcwDzk40uD8tYdAD5h2jWkD6b9iJwR9sVLU9ko_5JWBEQUZ3s5f1y94NKfUGxMfYDDydCaNbU39-U97BLokRjSYki-CuLKg8GUD5RO2WYX6jlwvP-DHE1AGQzKCmBwru33WDXPUX2FCbp8w5Ejfibg.svg" width="100%"/></span></span></a></div></div></td><td data-v-95bee609="" style="width:40%;"><div class="wiki-paragraph" data-v-95bee609=""><a class="wiki-link-externa ...
#  <div data-v-95bee609="" style="ou9T9n3p"></div>,
#  <div data-v-95bee609="" style="ou9T9n3p"><div data-v-95bee609="" style="ou9T9n3p"></div><div data-v-95bee609="" style="ou9T9n3p"><div class="wiki-heading-content" data-v-95bee609=""><div class="wiki-table-wrap table-center" data-v-95bee609="" style="width:650px"><table class="wiki-table" data-dark-style="background-color:#1c1d1f;" data-v-95bee609="" style="background-color:#fff; width:100%; border:2px solid #333;"><tbody data-v-95bee609=""><tr data-v-95bee609="" style="background-color:#333; color:#fff;"><td data-v-95bee609="" style="text-align:center;"><div class="wiki-paragraph" data-v-95bee609=""><strong data-v-95bee609="">평점 목록</strong></div></td></tr><tr data-v-95bee609=""><td data-v-95bee609="" style="text-align:center;"><div class="wiki-paragraph" data-v-95bee609=""><div data-v-95bee609="" style="margin:-5px -10px -5px -10px"><div data-v-95bee609=""><div data-v-95bee609="" style="margin:0"><div data-v-95bee609="" style="display:inline-table;display:none;width:100%;margin:-11px 0"><div class="wiki-table-wrap" data-v-95bee609="" style="width:100%"><table class="wiki-table" data-dark-style="background-color:#1c1d1f;" data-v-95bee609="" style="background-color:#fff; width:100%;"><tbody data-v-95bee609=""><tr data-v-95bee609=""><td data-v-95bee609="" style="background-color:#f6c700; width:20%;"><div class="wiki-paragraph" data-v-95bee609=""><div data-v-95bee609="" style="display:inline-block;margin:-5px;width:100px;max-width:25vw"><a class="wiki-link-internal" data-v-95bee609="" href="/w/IMDb" title="IMDb"><span class="wiki-image-align-normal" data-v-95bee609="" style="width:50%;"><span class="wiki-image-wrapper" data-v-95bee609="" style="width: 100%;"><img alt="IMDb 로고" data-v-95bee609="" src="//i.namu.wiki/i/XcJ0XFSm4_nq_AUYSCqxR7j50044CXfI1sgfRH3rDB1-vOD6zmzR2DuCM_jzYDsAR-SQEUc88e4Yfdik2hig9cXnRj3vg83LcZf8Q9tLBrZj2oLOZ3Ftp0i2PepZdOaP_7nlHF9F1sAjJlF1y4mm-w.svg" width="100%"/></span></span></a></div></div></td><td data-v-95bee609=""><div class="wiki-paragraph" data-v-95bee609=""><div data-v-95bee609="" style="display:inline-block;margin:0 5px"><a class="wiki-link-external" data-v-95bee609="" href="https://www.imdb.com/title/" rel="nofollow noopener ugc" target="_blank" title="https://www.imdb.com/title/"> <span data-dark-style="color:#fff;" data-v-95bee609="" style="color:#000">평점  / 10</span></a></div><div data-v-95bee609="" style="display:inline-block;display:none;margin:0 5px">(<a class="wiki-self-link" data-v-95bee609="" href="" title=""></a> 위<span class="wiki-size-down-3" data-v-95bee609=""><div data-v-95bee609="" style="display:inline-block;display:none;margin-left:0.5em">20XX-XX-XX 기준</div></span>)</div></div></td></tr></tbody></table></div></div><div data-v-95bee609="" style="display:inline-table;display:none;width:100%;margin:-11px 0"><div class="wiki-table-wrap" data-v-95bee609="" style="width:100%"><table class="wiki-table" data-dark-style="background-color:#1c1d1f;" data-v-95bee609="" style="background-color:#fff; width:100%;"><tbody data-v-95bee609=""><tr data-v-95bee609=""><td data-v-95bee609="" style="background-color:#f93208; width:20%;"><div class="wiki-paragraph" data-v-95bee609=""><div data-v-95bee609="" style="display:inline-block;margin:-5px;width:100px;max-width:25vw"><a class="wiki-link-internal" data-v-95bee609="" href="/w/%EB%A1%9C%ED%8A%BC%20%ED%86%A0%EB%A7%88%ED%86%A0" title="로튼 토마토"><span class="wiki-image-align-normal" data-v-95bee609="" style="width:80%;"><span class="wiki-image-wrapper" data-v-95bee609="" style="width: 100%;"><img alt="로튼 토마토 로고 화이트" data-v-95bee609="" src="//i.namu.wiki/i/UcwDzk40uD8tYdAD5h2jWkD6b9iJwR9sVLU9ko_5JWBEQUZ3s5f1y94NKfUGxMfYDDydCaNbU39-U97BLokRjSYki-CuLKg8GUD5RO2WYX6jlwvP-DHE1AGQzKCmBwru33WDXPUX2FCbp8w5Ejfibg.svg" width="100%"/></span></span></a></div></div></td><td data-v-95bee609="" style="width:40%;"><div class="wiki-paragraph" data-v-95bee609=""><a class="wiki-link-external" data-v-95bee609="" href="https://www.rottentomatoes.com/m/" rel="nofollow noopener ug ...
#  <div data-v-95bee609="" style="ou9T9n3p"></div>]

# %%
for i in evaluation[-1].select('a'):
    if ('http' not in i.attrs['title']) & (i.attrs['title'] != '') & (len(i.attrs['title']) < 30):
        try:
            if '네이버 영화' in table_data[-1]: # 네이버 영화는 동일한 데이터가 2번 입력됨
                del data[0]
        except:
            pass
        print(i.attrs)
        table_data.append(data)
        table_data.append(i.attrs['title'])
        data = []
    if (i.text != '') & bool(re.search(r'[\d%/]', i.text)) & (len(data) < 2) & ~bool(re.search(r'[\[\]]', i.text)): 
        # 데이터값에는 다양한 데이터가 들어가지만 주로 1/10 같은 분수 표현과 숫자로 구성 되어 있음. 
        # 또한 %도 들어가며 데이터는 최대 2개만 들어가는 것으로 보임
        data.append(i.text)
data
# Out:
# []

# %%
짱, 하이재킹, 타로, 댓글부대

# %%
pd_movies[1][0]
# Out:
#                   평가            점수1            점수2
# 0               IMDb       평점  / 10            NaN
# 1             로튼 토마토          신선도 %        관객 점수 %
# 2              메타크리틱   메타스코어  / 100       점수  / 10
# 3               알로시네   언론 별점  / 5.0   관객 별점  / 5.0
# 4         Letterboxd      별점  / 5.0            NaN
# 5             키노포이스크       별점  / 10            NaN
# 6             야후! 재팬      별점  / 5.0            NaN
# 7           Filmarks      별점  / 5.0            NaN
# 8                더우반       별점  / 10       별점  / 10
# 9              왓챠피디아      별점  / 5.0            NaN
# 10             키노라이츠      지수 85.48%   별점 3.3 / 5.0
# 11               네이버   평점 8.53 / 10            NaN
# 12  CGV Golden EGG지수         지수 95%            NaN
# 13             롯데시네마    평점 9.2 / 10            NaN
# 14              메가박스    평점 8.6 / 10            NaN
# 15              MRQE      평점  / 100            NaN
# 16              TMDB           점수 %            NaN
# 17             무비파일럿       평점  / 10            NaN
# 18         로저 이버트 닷컴        별점  / 4            NaN
# 19       MyDramaList       별점  / 10            NaN
# 20            Laftel      별점  / 5.0            NaN
# 21       MyAnimeList     평점  / 10.0            NaN
# 22    Google Play 무비      별점  / 5.0            NaN
# 23          네이버 시리즈온       별점  / 10            NaN
# 24         JustWatch           평점 %            NaN
# 25              맥스무비      평점  / 100            NaN
# 26              씨네21     씨네21  / 10       별점  / 10
# 27          CGV/해외사업       평점  / 10            NaN
# 28              엠파이어        별점  / 5            NaN

# %%
# 기존 코드
# for i in evaluation[-1].select('a'):
#     if ('http' not in i.attrs['title']) & (i.attrs['title'] != ''):
#         print('title',i.attrs['title'])
#     if (i.text != ''):
#         print(i.text)

# %% [markdown]
# # 기존 작업

# %%
pd_movies = []
for movie in movies:
    try:
        url = 'https://namu.wiki/w/' # %EC%82%B4%EC%9D%B8%EC%9D%98%20%EC%B6%94%EC%96%B5

        page = requests.get(url + movie)
        html = BeautifulSoup(page.text, 'html.parser')
        # html.select('#app > div > div.MMT57cZa.iHNYoQlC > div > div')
        soup = html.select('#app div div div div .wiki-paragraph') # .wiki-paragraph

        time.sleep(1) # 1초동안 정지
        
        lst = [] # 영화에 대한 정보를 담는 리스트
        st = 0
        for s in soup:
            if s.text != '':
                if s.text == '장르':
                    st = 1
                elif '개요' in s.text:
                    st = 0
                    break
                if st == 1:
                    lst.append(s.text)
            if '개요' in s.text:
                break
        lst.insert(0, '영화명')
        lst.insert(1, movie)
        df = pd.DataFrame(lst)
        df = pd.concat([df.iloc[::2].reset_index(drop=True), df.iloc[1::2].reset_index(drop=True)], axis=1)
        df.columns = ['kind', 'content']
        df.set_index(df.kind, inplace=True)
        df = df.drop('kind', axis=1)
        pd_movies.append(df)
    except Exception as e:
        print(e)

# %%
pd_movies[5]
# Out:
#                                                                                               content
# kind
# 영화명                                                                            우마무스메 프리티 더비 새로운 시대의 문
# 장르                                                                                            경마, 스포츠
# 감독                                                                                             야마모토 켄
# 시나리오 디렉터                                                                                코바리 테츠야(小針哲也)
# 스토리 원안                                                                                             콘티
# 야마모토 켄이시이 토시마사[1]나카야마 나오야[L]                                                                       연출
# 야마모토 켄후치모토 슈헤이쿠로야나기 토시마사랴오 청즈나카야마 나오야[L]오카모토 마나...                                                 각본
# 요시무라 키요코(吉村清子)                                                                                     원작
# Cygames                                                                                            제작
# ○○                                                                                                 주연
# 후지모토 유리, 우에사카 스미레, 오구라 유이, 후쿠시마 하루나 등                                                         캐릭터 디자인
# 야마자키 준                                                                                         총 작화감독
# 작화감독                                                 [ 펼치기 · 접기 ]오치아이 료스케(落合良亮)후쿠모토 요스케미야치후치모토 슈헤이...
# 액션 작화감독                                                                  야마모토 켄후치모토 슈헤이와타베 타카히로(渡部尭皓)
# 원화                                                   [ 펼치기 · 접기 ]스기타 슈마에나미 타케시미노시마 아야카히사타케 이오리(久武伊...
# 동화 검사                                                                                        니시타니 슈헤이
# 미술 감독                                                                                  와타나베 유스케(渡辺悠祐)
# 색채 설계                                                                                  이와이다 요우(岩井田 洋)
# 프롭 디자인                                                                                            오다시
# 촬영 감독                                                                           카와시타 유키(川下裕樹)후시하라 아카네
# 3D 감독                                                                                  나카노 요시노리(中野祥典)
# 편집                                                                                     키무라 카시코(木村佳史子)
# 음향 감독                                                                                         츠루오카 요타
# 음악                                                                                           요코야마 마사루
# 주제곡                                                                                                ○○
# 프로듀서                                                                                    아키타 미노루(秋田 穣)
# 애니메이션 프로듀서                                                                                   미조구치 타다시
# 제작사                                                                                   CygamesPictures
# 수입사                                                                                             애니플러스
# 배급사                                                                                          도호 애니플러스
# 개봉일                                                  2024년 5월 24일 2024년 7월 11일[4] 2024년 8월 1일 2024...
# 화면비                                                                                            2.39:1
# 상영 시간                                                                                      107분[5][6]
# 제작비                                                                                                ○○
# 월드 박스오피스                                                                                          $○○
# 북미 박스오피스                                                                                          $○○
# 대한민국 총 관객 수                                                                                   24,590명
# 스트리밍                                                                              (스트리밍 서비스사 이름) ▶[7]
# 상영 등급                                                                                          전체 관람가
# 공식 홈페이지                                                                                            |

# %%
# https://jalammar.github.io/illustrated-word2vec/
# 해당 주소를 참고하여 유사한 단어를 알아야함
# https://littlefoxdiary.tistory.com/42 자연어 처리 데이터셋 목록
# https://github.com/Espresso-AI/bertsum-korean?tab=readme-ov-file 텍스트 요약 모델 이용

# %%
# 문장이 들어왔을 때
# 불용어 처리
# 명사(영화명 포함)
# 명사와 유사한 단어의 장르를 탐색(혹은 영화)
# 질문과 유사한 줄거리인지 어떻게 판단하나?
# ex)로봇이 나와서 이기는 영화?
# ex)열린 결말의 영화를 추천해줘
